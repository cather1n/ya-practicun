# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Визуализация-распределений-параметров-каждой-выборки" data-toc-modified-id="Визуализация-распределений-параметров-каждой-выборки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Визуализация распределений параметров каждой выборки</a></span></li><li><span><a href="#Заполнение-пропущенных-значений" data-toc-modified-id="Заполнение-пропущенных-значений-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Заполнение пропущенных значений</a></span></li><li><span><a href="#Проверка-эффективности-обогащения" data-toc-modified-id="Проверка-эффективности-обогащения-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка эффективности обогащения</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Изменение-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-для-обучающей-выборки" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-для-обучающей-выборки-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах для обучающей выборки</a></span></li><li><span><a href="#Подготовка-обучающей-выборки" data-toc-modified-id="Подготовка-обучающей-выборки-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подготовка обучающей выборки</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Тестирование-модели-дерева-решений" data-toc-modified-id="Тестирование-модели-дерева-решений-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Тестирование модели дерева решений</a></span></li><li><span><a href="#Тестирование-модели-случайного-леса" data-toc-modified-id="Тестирование-модели-случайного-леса-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Тестирование модели случайного леса</a></span></li></ul></li></ul></li>></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer

# %%
sns.set(style="darkgrid")

# %% [markdown]
# Описание данных
# Технологический процесс
# Rougher feed — исходное сырье
# Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#  - Xanthate — ксантогенат (промотер, или активатор флотации);
#  - Sulphate — сульфат (на данном производстве сульфид натрия);
#  - Depressant — депрессант (силикат натрия).
# Rougher process (англ. «грубый процесс») — флотация
# Rougher tails — отвальные хвосты
# Float banks — флотационная установка
# Cleaner process — очистка
# Rougher Au — черновой концентрат золота
# Final Au — финальный концентрат золота
#
# Параметры этапов
# air amount — объём воздуха
# fluid levels — уровень жидкости
# feed size — размер гранул сырья
# feed rate — скорость подачи
#
# Наименование признаков
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
# Возможные значения для блока [этап]:
# rougher — флотация
# primary_cleaner — первичная очистка
# secondary_cleaner — вторичная очистка
# final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# input — параметры сырья
# output — параметры продукта
# state — параметры, характеризующие текущее состояние этапа
# calculation — расчётные характеристики

# %%
try:
    train = pd.read_csv('gold_recovery_train_new.csv')
    display(train)
except:
    train = pd.read_csv('/gold_recovery_train_new.csv')

# %%
try:
    test = pd.read_csv('gold_recovery_test_new.csv')
except:
    test = pd.read_csv('/gold_recovery_test_new.csv')

# %%
try:
    data = pd.read_csv('gold_recovery_full_new.csv')
except:
    data = pd.read_csv('/gold_recovery_full_new.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# Тип данных в столбце date неоходимо изменить на datetime.

# %%
train['date'] = pd.to_datetime(train['date'], format='%Y-%m-%dT%H:%M:%S')
test['date'] = pd.to_datetime(test['date'], format='%Y-%m-%dT%H:%M:%S')
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%dT%H:%M:%S')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# В обучающей и исходной выборке 87, а в тестовой выборке 53 столбца.

# %% [markdown]
# В тестовой выборке отсутсвуют признаки целевой призанак rougher.output.recovery и  final.output.recovery.
# Так же отсутствуют признаки - параметры продуктов
# после всех этапах технологического процесса (final.output.concentrate, final.output.tail, primary_cleaner.output.concentrate, primary_cleaner.output.tail,
# rougher.output.concentrate, rougher.output.tail, secondary_cleaner.output.tail), а так же расчетные характеристики (rougher.calculation.sulfate_to_au_concentrate,
# rougher.calculation.floatbank10_sulfate_to_au_feed, rougher.calculation.floatbank11_sulfate_to_au_feed, rougher.calculation.au_pb_ratio)

# %%
train.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14148.000000                 14148.000000
# mean                      5.142034                    10.132960
# std                       1.369586                     1.654930
# min                       0.000000                     0.000000
# 25%                       4.211620                     9.297355
# 50%                       4.994652                    10.297144
# 75%                       5.859540                    11.170603
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  13938.000000                 14149.000000
# mean                       9.202849                    44.003792
# std                        2.790516                     4.905261
# min                        0.000000                     0.000000
# ...

# %%
test.describe()
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5286.000000                       5285.000000
# mean                      174.839652                          8.683596
# std                        43.027080                          3.072050
# min                         2.566156                          0.003839
# 25%                       147.121401                          6.489555
# 50%                       177.828489                          8.052207
# 75%                       208.125438                         10.027764
# max                       265.983123                         40.000000
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5290.000000                     5286.000000
# mean                          7.266339                        1.383803
# std                           0.610219                        0.643474
# ...

# %%
data.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  19228.000000                 19439.000000
# mean                       9.501224                    44.076513
# std                        2.787537                     5.129784
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# ### Визуализация распределений параметров каждой выборки

# %%
train.hist(figsize = (50,20))
plt.show()

# %%
test.hist(figsize = (50,20))
plt.show()

# %%
data.hist(figsize = (50,20))
plt.show()

# %% [markdown]
# Большинство признаков имеют нормальное распределение, но есть и смещенное распределения. У некоторых признаков большое число значение в нуле. Возможно это выбросы.

# %% [markdown]
# ### Заполнение пропущенных значений

# %% [markdown]
# Так как по условиям соседние данные похожи воспользыемся методов ffill для заполнения пропущенных данных.

# %%
train = train.fillna(method='ffill')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         14149 non-null  float64
#  2   final.output.concentrate_pb                         14149 non-null  float64
#  3   final.output.concentrate_sol                        14149 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14149 non-null  float64
# ...

# %%
test = test.fillna(method='ffill')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   datetime64[ns]
#  1   primary_cleaner.input.sulfate               5290 non-null   float64
#  2   primary_cleaner.input.depressant            5290 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
data = data.fillna(method='ffill')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         19439 non-null  float64
#  2   final.output.concentrate_pb                         19439 non-null  float64
#  3   final.output.concentrate_sol                        19439 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19439 non-null  float64
#  7   final.output.tail_pb                                19439 non-null  float64
# ...

# %% [markdown]
# Проверка выборок на дубликаты.

# %%
train.duplicated().sum(), test.duplicated().sum(), data.duplicated().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# ### Проверка эффективности обогащения

# %%
mae_columns = ['rougher.output.recovery', 'rougher.output.concentrate_au', 'rougher.input.feed_au', 'rougher.output.tail_au']

recovery = train[mae_columns]
recovery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rougher.output.recovery        14149 non-null  float64
#  1   rougher.output.concentrate_au  14149 non-null  float64
#  2   rougher.input.feed_au          14149 non-null  float64
#  3   rougher.output.tail_au         14149 non-null  float64
# dtypes: float64(4)
# memory usage: 442.3 KB

# %%
recovery['mae_recovery'] = (recovery['rougher.output.concentrate_au'] * (recovery['rougher.input.feed_au']-
    recovery['rougher.output.tail_au'])) / (recovery['rougher.input.feed_au']*(recovery['rougher.output.concentrate_au']-
  recovery['rougher.output.tail_au'])) * 100
display(recovery.sample(5))
print('метрика MAE:', mean_absolute_error(recovery['rougher.output.recovery'], recovery['mae_recovery']))
# Out:
# <ipython-input-30-25df2ccafe07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recovery['mae_recovery'] = (recovery['rougher.output.concentrate_au'] * (recovery['rougher.input.feed_au']-
#        rougher.output.recovery  rougher.output.concentrate_au  \
# 1927                 86.814820                      19.038865
# 10535                89.754901                      20.941329
# 3712                 80.110344                      20.266422
# 8010                 83.897041                      19.418571
# 10824                93.838041                      19.658361
#
#        rougher.input.feed_au  rougher.output.tail_au  mae_recovery
# 1927                7.395918                1.471380     86.814820
# ...

# %% [markdown]
# Значение метрики MAE мало, расчитанный в датасете recovery верный и может быть применен в качестве целевого признака.

# %% [markdown]
# **Вывод:**
# В обучающей и исходной выборке 87, а в тестовой выборке 53 столбца. В следующем этапе необходимо будет исключить неинформативные столбцы из обучающей выборки.
# Пропущенные данные были заполнены методом ffill.
#
# Данные из столбца date необходимо перенести в индекс (выполнено в этапе анализа данных).

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Изменение концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
concentration = {
    'Au':['rougher.input.feed_au', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au'],
    'Ag':['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag'],
    'Pb':['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']}
 
for i in concentration:
    
    plt.figure(figsize=(15,7))
    sns.histplot(data[concentration[i]])
    plt.title(f'Гистограмма концентрации металла {i} в различных этапах очистки')
    plt.show()   
    print(f'Среднее значение концентрации металла {i}:')
    print( data[concentration[i]].mean())
# Out:
# Среднее значение концентрации металла Au:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64
# Среднее значение концентрации металла Ag:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168387
# dtype: float64
# Среднее значение концентрации металла Pb:
# rougher.input.feed_pb                    3.585096
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.810317
# final.output.concentrate_pb              9.978821
# dtype: float64

# %% [markdown]
# **Вывод:**
# При нулевых значениях есть выбросы, особенно они существенны для первичной очистки. Необходимо аномальные данные удалить.

# %% [markdown]
# Концентрация золота закономерно растет от начального к конечному этапу, то есть восстанволение золота из руды проходит успешно:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
#
#
# Начальная концентрация серебра ниже, чем после начального этапа, затем концентрация серебра падает:
# Среднее значение концентрации металла Ag:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168387
#
# Концентрация свинца растет от начального к коечному этапу
# Начальная концентрация свинца ниже, чем после начального этапа, затем концентрация серебра падает:
# Среднее значение концентрации металла Pb:
# rougher.input.feed_pb                    3.585096
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.810317
# final.output.concentrate_pb              9.978821

# %% [markdown]
# <font color='purple'><b> Вывод обновлен</b></font>

# %% [markdown]
# ### Распределение размеров гранул сырья на обучающей и тестовой выборках.

# %%
plt.figure(figsize=(15, 7))
sns.kdeplot(train['rougher.input.feed_size'], label='train rougher.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(test['rougher.input.feed_size'], label='test rougher.input.feed_size', alpha=0.5, shade=True)
plt.xlim([0, 150])
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности непрерывной величины')
plt.show()
print(train['rougher.input.feed_size'].describe())
print(test['rougher.input.feed_size'].describe())
# Out:
# <ipython-input-32-dfb443f20be5>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['rougher.input.feed_size'], label='train rougher.input.feed_size', alpha=0.5, shade=True)
# <ipython-input-32-dfb443f20be5>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(test['rougher.input.feed_size'], label='test rougher.input.feed_size', alpha=0.5, shade=True)
# count    14149.000000
# mean        60.239856
# std         23.005310
# min          9.659576
# 25%         48.966751
# 50%         55.269784
# 75%         66.007526
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64
# count    5290.000000
# mean       55.952754
# std        19.080334
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# ...

# %%
plt.figure(figsize=(15, 7))
sns.kdeplot(train['primary_cleaner.input.feed_size'], label='train rougher.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(test['primary_cleaner.input.feed_size'], label='test rougher.input.feed_size', alpha=0.5, shade=True)
plt.xlim([0, 15])
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности непрерывной величины')
plt.show()
print(train['rougher.input.feed_size'].describe())
print(test['rougher.input.feed_size'].describe())
# Out:
# <ipython-input-33-a45c0e30ba9a>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['primary_cleaner.input.feed_size'], label='train rougher.input.feed_size', alpha=0.5, shade=True)
# <ipython-input-33-a45c0e30ba9a>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(test['primary_cleaner.input.feed_size'], label='test rougher.input.feed_size', alpha=0.5, shade=True)
# count    14149.000000
# mean        60.239856
# std         23.005310
# min          9.659576
# 25%         48.966751
# 50%         55.269784
# 75%         66.007526
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64
# count    5290.000000
# mean       55.952754
# std        19.080334
# min         0.046369
# 25%        43.906504
# ...

# %% [markdown]
# **Вывод:**
# Распределения размеров гранул сырья на обучающей и тестовой выборке не сильно отличаются друг от друга, оценка модели будет правильной.

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
data['rougher.input.feed_all'] = data['rougher.input.feed_au'] \
    + data['rougher.input.feed_ag'] \
    + data['rougher.input.feed_pb'] \
    + data['rougher.input.feed_sol']

data['rougher.output_all'] = data['rougher.output.concentrate_au'] \
    + data['rougher.output.concentrate_ag'] \
    + data['rougher.output.concentrate_pb'] \
    + data['rougher.output.concentrate_sol']

data['final.output_all'] = data['final.output.concentrate_au'] \
    + data['final.output.concentrate_ag'] \
    + data['final.output.concentrate_pb'] \
    + data['final.output.concentrate_sol']

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(data['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
sns.kdeplot(data['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
sns.kdeplot(data['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)   
plt.legend(labels=['rougher.input.feed_all', 'rougher.output.concentrate', 'final.output.concentrate'],
           loc='upper left')
plt.title(f'Суммарная концентрация всех веществ на разных стадиях')
plt.show()
# Out:
# <ipython-input-35-c47049bb3a8c>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
# <ipython-input-35-c47049bb3a8c>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
# <ipython-input-35-c47049bb3a8c>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)

# %% [markdown]
# **Вывод:**
# Суммарная концентрация веществ увеличивается с каждой стадией процесса обогащения, так как при обработке вымываются лишние примеси и подсадочные реагенты.
# При нулевых значениях есть выбросы, особенно они существенны для первичной очистки. Необходимо аномальные данные удалить.

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data = data[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']], palette = 'Blues_r')
plt.title('Ящик с усами для суммарной концентрации всех веществ на разных стадиях')
plt.ylabel('Значения')
plt.show()
data[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']].describe()
# Out:
#        rougher.input.feed_all  rougher.output_all  final.output_all
# count            19439.000000        19439.000000      19439.000000
# mean                57.320789           68.170865         68.653624
# std                  7.212680           12.491279          7.427536
# min                  0.040000            0.000000          0.000000
# 25%                 53.557679           66.012495         67.932362
# 50%                 57.594391           70.181495         69.598444
# 75%                 61.953459           74.356904         71.368472
# max                 76.978947           88.140119         80.210644

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах для обучающей выборки

# %%
train['rougher.input.feed_all'] = train['rougher.input.feed_au'] \
    + train['rougher.input.feed_ag'] \
    + train['rougher.input.feed_pb'] \
    + train['rougher.input.feed_sol']

train['rougher.output_all'] = train['rougher.output.concentrate_au'] \
    + train['rougher.output.concentrate_ag'] \
    + train['rougher.output.concentrate_pb'] \
    + train['rougher.output.concentrate_sol']

train['final.output_all'] = train['final.output.concentrate_au'] \
    + train['final.output.concentrate_ag'] \
    + train['final.output.concentrate_pb'] \
    + train['final.output.concentrate_sol']

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(train['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
sns.kdeplot(train['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
sns.kdeplot(train['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)   
plt.legend(labels=['rougher.input.feed_all', 'rougher.output.concentrate', 'final.output.concentrate'],
           loc='upper left')
plt.title(f'Суммарная концентрация всех веществ на разных стадиях для обучающей выборки')
plt.show()
# Out:
# <ipython-input-38-d18def243d23>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
# <ipython-input-38-d18def243d23>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
# <ipython-input-38-d18def243d23>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data = train[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']], palette = 'Blues_r')
plt.title('Ящик с усами для суммарной концентрации всех веществ на разных стадиях для обучающей выборки')
plt.ylabel('Значения')
plt.show()
data[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']].describe()
# Out:
#        rougher.input.feed_all  rougher.output_all  final.output_all
# count            19439.000000        19439.000000      19439.000000
# mean                57.320789           68.170865         68.653624
# std                  7.212680           12.491279          7.427536
# min                  0.040000            0.000000          0.000000
# 25%                 53.557679           66.012495         67.932362
# 50%                 57.594391           70.181495         69.598444
# 75%                 61.953459           74.356904         71.368472
# max                 76.978947           88.140119         80.210644

# %% [markdown]
# **Вывод:**
# Для обучающей выборки суммарная концентрация веществ увеличивается с каждой стадией процесса обогащения.
# При нулевых значениях есть выбросы, особенно они существенны для первичной очистки. Необходимо аномальные данные удалить.

# %% [markdown]
# ### Подготовка обучающей выборки

# %% [markdown]
# Первоначально для обучающей выборки было удалены все выбросы для столбца rougher.output_all, но количество удаленных данных составило больше 15%, по этому было решено удалить только значения не равные 0.

# %%
train.shape
# Out:
# (14149, 90)

# %%
train = train.loc[(train['rougher.input.feed_all'] > 0)]
train = train.loc[(train['rougher.output_all'] > 0)]
train = train.loc[(train['final.output_all'] > 0)]
train.shape
# Out:
# (13795, 90)

# %% [markdown]
# Удаленные данные составили ~3%.~ 2.5%

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(train['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
sns.kdeplot(train['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
sns.kdeplot(train['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)   
plt.legend(labels=['rougher.input.feed_all', 'rougher.output.concentrate', 'final.output.concentrate'],
           loc='upper left')
plt.title(f'Суммарная концентрация всех веществ на разных стадиях для обучающей выборки')
plt.show()
# Out:
# <ipython-input-42-d18def243d23>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['rougher.input.feed_all'], label='rougher.input.feed_all', alpha=0.5, shade=True)
# <ipython-input-42-d18def243d23>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['rougher.output_all'], label='rougher.output.concentrate', alpha=0.5, shade=True)
# <ipython-input-42-d18def243d23>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(train['final.output_all'], label='final.output.concentrate', alpha=0.5, shade=True)

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data = train[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']], palette = 'Blues_r')
plt.title('Ящик с усами для суммарной концентрации всех веществ на разных стадиях для обучающей выборки')
plt.ylabel('Значения')
plt.show()
data[['rougher.input.feed_all', 'rougher.output_all', 'final.output_all']].describe()
# Out:
#        rougher.input.feed_all  rougher.output_all  final.output_all
# count            19439.000000        19439.000000      19439.000000
# mean                57.320789           68.170865         68.653624
# std                  7.212680           12.491279          7.427536
# min                  0.040000            0.000000          0.000000
# 25%                 53.557679           66.012495         67.932362
# 50%                 57.594391           70.181495         69.598444
# 75%                 61.953459           74.356904         71.368472
# max                 76.978947           88.140119         80.210644

# %% [markdown]
# Средниее значение и медиана rougher.output_all, primary_cleaner.output_all и final.output_all почти не изменились.

# %% [markdown]
# Для удобства добавим целевые признаки в тестовую выборку

# %%
test = test.merge(data[['final.output.recovery', 'rougher.output.recovery', 'date']], how='left', on='date')

# %%
train = train[test.columns]

# %% [markdown]
# Для избежания ошибок при построении модели перенесем данные из столбца date в индекс

# %%
train = train.set_index('date')
#train_new = train_new.set_index('date')
test = test.set_index('date')
data = data.set_index('date')

# %% [markdown]
# ## Модель

# %%
RANDOM_STATE = 12345

# %% [markdown]
# Функция для вычисления итогового SMAPE

# %%
def smape (target, predictions):
    smape_num = abs(predictions - target)
    smape_den = (abs(target) + abs(predictions)) / 2
    total = (smape_num / smape_den).sum()
    smape = (1 / len(target)) * total * 100
    return smape

# %% [markdown]
# Выделение features, target для обучающей и тренировной выборки

# %%
train_features_rougher = train.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
train_target_rougher = train['rougher.output.recovery']
train_features_final = train.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
train_target_final = train['final.output.recovery']

# %%
test_features_rougher = test.drop(['rougher.output.recovery','final.output.recovery'], axis =1)
test_target_rougher = test['rougher.output.recovery']
test_features_final = test.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
test_target_final = test['final.output.recovery']

# %% [markdown]
# Функция кросс-валидации и функция расчета SMAPE для разных моделей

# %%
def cross_val (model, features, target):
    scores = cross_val_score(model, features, 
                                   target, scoring=make_scorer(smape, greater_is_better=True), cv=5,n_jobs=-1)
    smape_res = np.mean(scores)
    return smape_res

# %%
def ml(model):
    smape_rougher = cross_val (model, train_features_rougher, train_target_rougher)
    smape_final = cross_val (model, train_features_final, train_target_final)
    smape_end = 0.25 * smape_rougher + 0.75 * smape_final
    print('SMAPE на этапе флотации: {:.2f}'.format(smape_rougher))
    print('SMAPE на финальном этапе: {:.2f}'.format(smape_final))
    print('Итоговая метрика SMAPE: {:.2f}'.format(smape_end))

# %% [markdown]
# Масштабируем признаки для этапа флотации и для финального этапа

# %%
scaler_rougher = StandardScaler()
scaler_rougher.fit(train_features_rougher)

train_col_rougher = train_features_rougher.columns

train_features_rougher = scaler_rougher.transform(train_features_rougher)
train_features_rougher = pd.DataFrame(train_features_rougher, columns = train_col_rougher)

# %%
scaler_final = StandardScaler()
scaler_final.fit(train_features_final)

train_col_final = train_features_final.columns

train_features_final = scaler_final.transform(train_features_final)
train_features_final = pd.DataFrame(train_features_final, columns = train_col_final)

# %%
model = DecisionTreeRegressor()
ml(model)
# Out:
# SMAPE на этапе флотации: 11.02
# SMAPE на финальном этапе: 16.62
# Итоговая метрика SMAPE: 15.22

# %%
# %%time
model = RandomForestRegressor()
ml(model)
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.89
# Итоговая метрика SMAPE: 9.19
# CPU times: user 3.31 s, sys: 364 ms, total: 3.67 s
# Wall time: 10min 4s

# %%
model = LinearRegression()
ml(model)
# Out:
# SMAPE на этапе флотации: 7.27
# SMAPE на финальном этапе: 10.99
# Итоговая метрика SMAPE: 10.06

# %%
model = DummyRegressor()
ml(model)
# Out:
# SMAPE на этапе флотации: 7.80
# SMAPE на финальном этапе: 10.45
# Итоговая метрика SMAPE: 9.79

# %% [markdown]
# Для модели RandomForestRegressor итоговое значение SMAPE составляет 9.3, модель DummyRegressor показала лучше значения (SMAPE 9.79), чем DecisionTreeRegressor и  LinearRegression. Для улучшения качества модели произведем настройку параметров модели.

# %% [markdown]
# ### Дерево решений

# %%
# %%time
best_smape = 15
best_model = None
best_depth = 0
for depth in range (1, 40):
    model = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=depth) 
    smape_rougher = cross_val (model, train_features_rougher, train_target_rougher)
    smape_final = cross_val (model, train_features_final, train_target_final)
    smape_end = 0.25 * smape_rougher + 0.75 * smape_final
    if smape_end < best_smape:
        best_smape = smape_end
        best_depth = depth
print("Итоговая метрика SMAPE наилучшей модели: {:.2f}".format(best_smape), "Максимальная глубина:", best_depth)
# Out:
# Итоговая метрика SMAPE наилучшей модели: 8.86 Максимальная глубина: 3
# CPU times: user 3.01 s, sys: 594 ms, total: 3.61 s
# Wall time: 4min 44s

# %%
# %%time
model_dtr1 = DecisionTreeRegressor(random_state=RANDOM_STATE)
parameters = {'max_depth': [x for x in range(1, 20)]}
grid_dtr1 = GridSearchCV(model_dtr1,
                               parameters,  n_jobs=-1,
                               scoring=make_scorer(smape, greater_is_better=False))
grid_dtr1.fit(train_features_rougher, train_target_rougher)
print(grid_dtr1.best_params_)
# Out:
# {'max_depth': 3}
# CPU times: user 845 ms, sys: 64.1 ms, total: 909 ms
# Wall time: 51.7 s

# %%
# %%time
model_dtr2 = DecisionTreeRegressor(random_state=RANDOM_STATE)
parameters = {'max_depth': [x for x in range(1, 20)]}
grid_dtr2 = GridSearchCV(model_dtr2, parameters,  n_jobs=-1, scoring=make_scorer(smape, greater_is_better=False))
grid_dtr2.fit(train_features_final, train_target_final)
print(grid_dtr2.best_params_)
# Out:
# {'max_depth': 2}
# CPU times: user 713 ms, sys: 63.6 ms, total: 776 ms
# Wall time: 47.8 s

# %%
model_dtr = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=3) 
smape_rougher = cross_val (model_dtr, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_dtr, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для дерева решений: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.45
# Итоговая метрика SMAPE для дерева решений: 8.86

# %%
model_dtr1 = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=3) 
model_dtr2 = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=2) 
smape_rougher = cross_val (model_dtr1, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_dtr2, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для дерева решений: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.39
# Итоговая метрика SMAPE для дерева решений: 8.81

# %%
print(grid_dtr1.best_score_ * -1)
print(grid_dtr2.best_score_ * -1)
# Out:
# 7.071138009679627
# 9.386114676974554

# %%
smape_rougher = grid_dtr1.best_score_ * -1
smape_final = grid_dtr2.best_score_ * -1
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для дерева решений: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.39
# Итоговая метрика SMAPE для дерева решений: 8.81

# %% [markdown]
# **Вывод:**
#     Наилучшее значение итоговой метрики SMAPE для лучшей модели дерева решений составляет 8.91%.

# %% [markdown]
# ### Случайный лес

# %%
# %%time
best_smape = 10
best_est = 0
best_depth = 0
for est in range(10, 100, 10):
    for depth in range (1, 10):
        model = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=est, max_depth=depth)
        smape_rougher = cross_val (model, train_features_rougher, train_target_rougher)
        smape_final = cross_val (model, train_features_final, train_target_final)
        smape_end = 0.25 * smape_rougher + 0.75 * smape_final
        if smape_end < best_smape:
            best_smape = smape_end
            best_est = est
            best_depth = depth        
print('Итоговая метрика SMAPE наилучшей модели: {:.2f}, Количество деревьев {:.2f}  Максимальная глубина: {:.2f}'.format(best_smape, best_est, best_depth))
# Out:
# Итоговая метрика SMAPE наилучшей модели: 8.47, Количество деревьев 70.00  Максимальная глубина: 4.00
# CPU times: user 43.3 s, sys: 5.71 s, total: 49 s
# Wall time: 2h 5min 50s

# %%
# %%time
model_rfr = RandomForestRegressor(random_state=RANDOM_STATE)
parameters = { 'max_depth': [x for x in range(1, 10)],
               'n_estimators': [x for x in range(10, 101, 10)]
             }
grid_rfr = GridSearchCV(model_rfr, parameters, n_jobs=-1, scoring=make_scorer(smape, greater_is_better=False))
grid_rfr.fit(train_features_rougher, train_target_rougher)
print(grid_rfr.best_params_)
# Out:
# {'max_depth': 5, 'n_estimators': 100}
# CPU times: user 54.4 s, sys: 2.94 s, total: 57.4 s
# Wall time: 1h 12min 12s

# %%
# %%time
model_rfr = RandomForestRegressor(random_state=RANDOM_STATE)
parameters = { 'max_depth': [x for x in range(1, 10)],
               'n_estimators': [x for x in range(10, 101, 10)]
             }
grid_rfr = GridSearchCV(model_rfr, parameters, n_jobs=-1, scoring=make_scorer(smape, greater_is_better=False))
grid_rfr.fit(train_features_final, train_target_final)
print(grid_rfr.best_params_)
# Out:
# {'max_depth': 4, 'n_estimators': 70}
# CPU times: user 41.3 s, sys: 2.98 s, total: 44.2 s
# Wall time: 1h 12min 29s

# %%
model_rfr = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=80, max_depth=4)
smape_rougher = cross_val (model_rfr, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_rfr, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для случайного леса: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 6.76
# SMAPE на финальном этапе: 9.05
# Итоговая метрика SMAPE для случайного леса: 8.48

# %%
model_rfr1 = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=90, max_depth=3)
model_rfr2 = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=50, max_depth=4)
smape_rougher = cross_val (model_rfr1, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_rfr2, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для случайного леса: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 6.79
# SMAPE на финальном этапе: 9.08
# Итоговая метрика SMAPE для случайного леса: 8.51

# %% [markdown]
# Наилучшее значение итоговой метрики SMAPE для лучшей модели случайного леса при использовании 2 разных моделей для этапа флотации и финального этапа для составляет 8.42%.

# %% [markdown]
# ### Линейная регрессия

# %%
model_lr = LinearRegression()
smape_rougher = cross_val (model_lr, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_lr, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для случайного леса: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.27
# SMAPE на финальном этапе: 10.99
# Итоговая метрика SMAPE для случайного леса: 10.06

# %% [markdown]
# ### Тестирование модели

# %%
test_col_rougher = test_features_rougher.columns

test_features_rougher = scaler_rougher.transform(test_features_rougher)
test_features_rougher = pd.DataFrame(test_features_rougher, columns = test_col_rougher)

# %%
test_col_final = test_features_final.columns

test_features_final = scaler_final.transform(test_features_final)
test_features_final = pd.DataFrame(test_features_final, columns = test_col_final)

# %% [markdown]
# #### Тестирование модели дерева решений

# %% [markdown]
# Тестирование модели дерева решений, параметры которой были получены GridSearchCV

# %%
model_dtr1 = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=3) 
model_dtr2 = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=2) 
smape_rougher = cross_val (model_dtr1, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_dtr2, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для дерева решений: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.39
# Итоговая метрика SMAPE для дерева решений: 8.81

# %%
model_rougher = model_dtr1
model_rougher.fit(train_features_rougher, train_target_rougher)
predictions_rougher = model_rougher.predict(test_features_rougher)

model_final = model_dtr2
model_final.fit(train_features_final, train_target_final)
predictions_final = model_final.predict(test_features_final)
    
smape_rougher = smape(test_target_rougher, predictions_rougher)
smape_final = smape(test_target_final, predictions_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print('SMAPE на этапе флотации на тестовой выборке: {:.2f}'.format(smape_rougher))
print('SMAPE на финальном этапе на тестовой выборке {:.2f}'.format(smape_final)) 
print('Итоговая метрика SMAPE на тестовой выборке: {:.2f}'.format(smape_end))
# Out:
# SMAPE на этапе флотации на тестовой выборке: 8.92
# SMAPE на финальном этапе на тестовой выборке 9.92
# Итоговая метрика SMAPE на тестовой выборке: 9.67

# %% [markdown]
# Тестирование модели дерева решений, параметры которой были получены циклом

# %%
model_dtr = DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=3) 
smape_rougher = cross_val (model_dtr, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_dtr, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для дерева решений: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 7.07
# SMAPE на финальном этапе: 9.45
# Итоговая метрика SMAPE для дерева решений: 8.86

# %%
model_rougher = model_dtr
model_rougher.fit(train_features_rougher, train_target_rougher)
predictions_rougher = model_rougher.predict(test_features_rougher)
    

model_final = model_dtr
model_final.fit(train_features_final, train_target_final)
predictions_final = model_final.predict(test_features_final)
    
smape_rougher = smape(test_target_rougher, predictions_rougher)
smape_final = smape(test_target_final, predictions_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print('SMAPE на этапе флотации на тестовой выборке: {:.2f}'.format(smape_rougher))
print('SMAPE на финальном этапе на тестовой выборке {:.2f}'.format(smape_final)) 
print('Итоговая метрика SMAPE на тестовой выборке: {:.2f}'.format(smape_end))
# Out:
# SMAPE на этапе флотации на тестовой выборке: 8.92
# SMAPE на финальном этапе на тестовой выборке 9.91
# Итоговая метрика SMAPE на тестовой выборке: 9.66

# %% [markdown]
# #### Тестирование модели случайного леса

# %% [markdown]
# Тестирование модели случайного леса, параметры которой были получены GridSearchCV

# %%
model_rfr1 = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=90, max_depth=3)
model_rfr2 = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=50, max_depth=4)
smape_rougher = cross_val (model_rfr1, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_rfr2, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для случайного леса: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 6.79
# SMAPE на финальном этапе: 9.08
# Итоговая метрика SMAPE для случайного леса: 8.51

# %%
model_rougher = model_rfr1
model_rougher.fit(train_features_rougher, train_target_rougher)
predictions_rougher = model_rougher.predict(test_features_rougher)
    

model_final = model_rfr2
model_final.fit(train_features_final, train_target_final)
predictions_final = model_final.predict(test_features_final)
    
smape_rougher = smape(test_target_rougher, predictions_rougher)
smape_final = smape(test_target_final, predictions_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print('SMAPE на этапе флотации на тестовой выборке: {:.2f}'.format(smape_rougher))
print('SMAPE на финальном этапе на тестовой выборке {:.2f}'.format(smape_final)) 
print('Итоговая метрика SMAPE на тестовой выборке: {:.2f}'.format(smape_end))
# Out:
# SMAPE на этапе флотации на тестовой выборке: 8.75
# SMAPE на финальном этапе на тестовой выборке 9.87
# Итоговая метрика SMAPE на тестовой выборке: 9.59

# %% [markdown]
# Тестирование модели случайного леса, параметры которой были получены циклом

# %%
model_rfr = RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=80, max_depth=4)
smape_rougher = cross_val (model_rfr, train_features_rougher, train_target_rougher)
smape_final = cross_val (model_rfr, train_features_final, train_target_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print("SMAPE на этапе флотации: {:.2f}".format(smape_rougher))
print("SMAPE на финальном этапе: {:.2f}".format(smape_final)) 
print("Итоговая метрика SMAPE для случайного леса: {:.2f}".format(smape_end))
# Out:
# SMAPE на этапе флотации: 6.76
# SMAPE на финальном этапе: 9.05
# Итоговая метрика SMAPE для случайного леса: 8.48

# %%
model_rougher = model_rfr
model_rougher.fit(train_features_rougher, train_target_rougher)
predictions_rougher = model_rougher.predict(test_features_rougher)
    

model_final = model_rfr
model_final.fit(train_features_final, train_target_final)
predictions_final = model_final.predict(test_features_final)
    
smape_rougher = smape(test_target_rougher, predictions_rougher)
smape_final = smape(test_target_final, predictions_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print('SMAPE на этапе флотации на тестовой выборке: {:.2f}'.format(smape_rougher))
print('SMAPE на финальном этапе на тестовой выборке {:.2f}'.format(smape_final)) 
print('Итоговая метрика SMAPE на тестовой выборке: {:.2f}'.format(smape_end))
# Out:
# SMAPE на этапе флотации на тестовой выборке: 8.48
# SMAPE на финальном этапе на тестовой выборке 9.77
# Итоговая метрика SMAPE на тестовой выборке: 9.45

# %%
model_rougher = DummyRegressor()
model_rougher.fit(train_features_rougher, train_target_rougher)
predictions_rougher = model_rougher.predict(test_features_rougher)
    

model_final = DummyRegressor()
model_final.fit(train_features_final, train_target_final)
predictions_final = model_final.predict(test_features_final)
    
smape_rougher = smape(test_target_rougher, predictions_rougher)
smape_final = smape(test_target_final, predictions_final)
smape_end = 0.25 * smape_rougher + 0.75 * smape_final
print('SMAPE на этапе флотации на тестовой выборке: {:.2f}'.format(smape_rougher))
print('SMAPE на финальном этапе на тестовой выборке {:.2f}'.format(smape_final)) 
print('Итоговая метрика SMAPE на тестовой выборке: {:.2f}'.format(smape_end))
# Out:
# SMAPE на этапе флотации на тестовой выборке: 9.07
# SMAPE на финальном этапе на тестовой выборке 10.07
# Итоговая метрика SMAPE на тестовой выборке: 9.82

# %% [markdown]
# Сравнение в константной моделью DummyRegressor показало адекватность полученной модели. Итоговая метрика SMAPE на тестовой выборке для DummyRegressor: 9.82.

# %% [markdown]
# **Выводы:**
#
# Обычающая выборка и исходны данные имеют больший размер, чем тестовая выборка. В обучающей и исходной выборке 87, а в тестовой выборке 53 столбца.
# Пропущенные данные всех выборок были заполнены методом ffill.
# Данные из столбца date необходимо перенести в индекс (выполнено в этапе анализа данных).
#
#
# Построены гистограммы концентрации металлов в различных этапах очистки, выявлены аномалии в нуле. Возможно ошибки возникли в результате сбоя.
#
# Распределения размеров гранул сырья на обучающей и тестовой выборке не сильно отличаются друг от друга, оценка модели будет правильной.
#
# Проведено исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# Для обучающей выборки суммарная концентрация веществ увеличивается с каждой стадией процесса обогащения.
#
# Построены модели DecisionTreeRegressor,  RandomForestRegressor, RandomForestRegressor и DummyRegressor.
#
# Наилучшее значение итоговой метрики SMAPE для лучшей модели дерева решений на обучающей выборке составляет 8.86%, на тестовой выборке 9.66%
#
# Наилучшее значение итоговой метрики SMAPE для лучшей модели случайного леса на обучающей выборке составляет 8.48%, на тестовой выборке 9.45%.
#
# Обе построенные модели в сравнении с DummyRegressor адекватны.
#
# Наилучшие показатели для тестовой выборки у модели случайного леса RandomForestRegressor с количеством деревьев 80 и глубиной 4.

# %% [markdown]
# Сравнение в константной моделью DummyRegressor показало адекватность полученной модели.
